# %%
#Importing libraries for visualization, graphs, and modeling
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
sns.set()
from pylab import *
from scipy import special, optimize
import sys
import os

# %%
#Download dataset
prod=pd.read_csv('/Users/LindseyTakeuchi/Downloads/time_series_60min_singleindex.csv',
                        usecols=(lambda s: s.startswith('utc') | s.startswith('DE')),
                        parse_dates=[0], index_col=0)

# %%
prod.head()
# Out:
#                      DE_load_entsoe_power_statistics  \
# utc_timestamp
# 2005-12-31 23:00:00                          47823.0
# 2006-01-01 00:00:00                          47823.0
# 2006-01-01 01:00:00                          43444.0
# 2006-01-01 02:00:00                          41432.0
# 2006-01-01 03:00:00                          40508.0
#
#                      DE_load_entsoe_transparency  DE_price_day_ahead  \
# utc_timestamp
# 2005-12-31 23:00:00                          NaN               32.10
# 2006-01-01 00:00:00                          NaN               30.07
# 2006-01-01 01:00:00                          NaN               27.94
# 2006-01-01 02:00:00                          NaN               21.71
# 2006-01-01 03:00:00                          NaN                8.24
#
#                      DE_solar_capacity  DE_solar_generation_actual  \
# utc_timestamp
# 2005-12-31 23:00:00             2028.0                         NaN
# ...

# %%
prod.describe()
# Out:
#        DE_load_entsoe_power_statistics  DE_load_entsoe_transparency  \
# count                    107351.000000                 30672.000000
# mean                      55898.197877                 54682.893616
# std                       10148.155613                 11751.923786
# min                       28984.000000                     0.000000
# 25%                       47473.500000                 46692.000000
# 50%                       55829.000000                 54898.000000
# 75%                       64554.000000                 64359.250000
# max                       79884.000000                 79063.000000
#
#        DE_price_day_ahead  DE_solar_capacity  DE_solar_generation_actual  \
# count       108817.000000      105193.000000                54074.000000
# mean            41.180829       22514.822669                 3671.266986
# std             24.850903       15029.817756                 5703.348311
# ...

# %%
prod.isna().sum().sort_values(ascending=False)
# Out:
# DE_wind_offshore_profile                        91272
# DE_wind_onshore_profile                         91272
# DE_wind_onshore_generation_actual               89761
# DE_wind_offshore_generation_actual              87650
# DE_50hertz_wind_offshore_generation_forecast    87648
# DE_50hertz_wind_onshore_generation_actual       87648
# DE_50hertz_wind_onshore_generation_forecast     87648
# DE_50hertz_wind_offshore_generation_actual      87648
# DE_AT_LU_price_day_ahead                        79008
# DE_load_entsoe_transparency                     78145
# DE_solar_profile                                56254
# DE_solar_generation_actual                      54743
# DE_50hertz_solar_generation_forecast            52584
# DE_50hertz_solar_generation_actual              52584
# DE_transnetbw_solar_generation_forecast         44471
# DE_transnetbw_solar_generation_actual           43872
# DE_amprion_solar_generation_forecast            41520
# ...
